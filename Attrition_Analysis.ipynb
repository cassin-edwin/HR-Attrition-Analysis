# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
df = pd.read_csv('C:/Users/cassin.thangam.edwin/Downloads/ibm-hr-analytics-attrition-dataset/WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
df.isnull().all()
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# Over18                      False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.drop(['Over18','StandardHours'], inplace = True, axis =1)

# %%
df.head(3)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
#
#    ...  PerformanceRating RelationshipSatisfaction  StockOptionLevel  \
# 0  ...                  3                        1                 0
# 1  ...                  4                        4                 1
# 2  ...                  3                        2                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# ...

# %%
df.drop('EmployeeCount', inplace = True, axis =1)

# %%
df.shape
# Out:
# (1470, 32)

# %%
df = df.rename(columns = {'Attrition' : 'turnover'})

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# ...

# %%
df.head(3)
# Out:
#    Age turnover     BusinessTravel  DailyRate              Department  \
# 0   41      Yes      Travel_Rarely       1102                   Sales
# 1   49       No  Travel_Frequently        279  Research & Development
# 2   37      Yes      Travel_Rarely       1373  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
#
#    EnvironmentSatisfaction  ... PerformanceRating  RelationshipSatisfaction  \
# 0                        2  ...                 3                         1
# 1                        3  ...                 4                         4
# 2                        4  ...                 3                         2
#
#    StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# ...

# %%
df[df['turnover'] == 'Yes'].head()
# Out:
#     Age turnover BusinessTravel  DailyRate              Department  \
# 0    41      Yes  Travel_Rarely       1102                   Sales
# 2    37      Yes  Travel_Rarely       1373  Research & Development
# 14   28      Yes  Travel_Rarely        103  Research & Development
# 21   36      Yes  Travel_Rarely       1218                   Sales
# 24   34      Yes  Travel_Rarely        699  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                  1          2  Life Sciences               1
# 2                  2          2          Other               4
# 14                24          3  Life Sciences              19
# 21                 9          4  Life Sciences              27
# 24                 6          1        Medical              31
#
#     EnvironmentSatisfaction  ... PerformanceRating  RelationshipSatisfaction  \
# 0                         2  ...                 3                         1
# ...

# %%
target_map = {"Yes" : 1, "No" : 0}

df['turnover_num'] = df['turnover'].apply(lambda x : target_map[x])

# %%
df.head(3)
# Out:
#    Age turnover     BusinessTravel  DailyRate              Department  \
# 0   41      Yes      Travel_Rarely       1102                   Sales
# 1   49       No  Travel_Frequently        279  Research & Development
# 2   37      Yes      Travel_Rarely       1373  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StockOptionLevel  \
# 0                        2  ...                        1                 0
# 1                        3  ...                        4                 1
# 2                        4  ...                        2                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# ...

# %%
df.drop(columns  = 'turnover', inplace = True, axis = 1)

# %%
df.head(5)
# Out:
#    Age     BusinessTravel              Department  DistanceFromHome  \
# 0   41      Travel_Rarely                   Sales                 1
# 1   49  Travel_Frequently  Research & Development                 8
# 2   37      Travel_Rarely  Research & Development                 2
# 3   33  Travel_Frequently  Research & Development                 3
# 4   27      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          2  Life Sciences               1                        2  Female
# 1          1  Life Sciences               2                        3    Male
# 2          2          Other               4                        4    Male
# 3          4  Life Sciences               5                        4  Female
# 4          1        Medical               7                        1    Male
#
#    JobInvolvement  ...  RelationshipSatisfaction StockOptionLevel  \
# ...

# %%
a = corr.columns.values

# %%
corr = df.corr()
f, ax = plt.subplots(figsize=(25,25))
sns.heatmap(corr, xticklabels = a, yticklabels = a,cmap = 'winter',ax =ax, annot = True)

# %%
df.drop(columns = ['DailyRate','HourlyRate'], inplace = True, axis =1)

# %%
df.head()
# Out:
#    Age     BusinessTravel              Department  DistanceFromHome  \
# 0   41      Travel_Rarely                   Sales                 1
# 1   49  Travel_Frequently  Research & Development                 8
# 2   37      Travel_Rarely  Research & Development                 2
# 3   33  Travel_Frequently  Research & Development                 3
# 4   27      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0          2  Life Sciences               1                        2  Female
# 1          1  Life Sciences               2                        3    Male
# 2          2          Other               4                        4    Male
# 3          4  Life Sciences               5                        4  Female
# 4          1        Medical               7                        1    Male
#
#    JobInvolvement  ...  RelationshipSatisfaction StockOptionLevel  \
# ...

# %%
sns.barplot(data = df, x = 'JobInvolvement', y = 'YearsWithCurrManager', hue = 'Gender')

# %%
sns.catplot(data = df, x= 'PerformanceRating', y = 'PercentSalaryHike', col = 'Gender', hue = 'BusinessTravel', kind = 'violin')

# %%
sns.boxplot(data = df, x = 'Gender', y = 'TotalWorkingYears', hue = 'Department')
plt.legend(bbox_to_anchor=(1.5,1),loc="upper left")

# %%
ab = sns.barplot(data = df, x = 'RelationshipSatisfaction', y = 'turnover_num')

# %%
df.turnover_num.value_counts()
# Out:
# 0    1233
# 1     237
# Name: turnover_num, dtype: int64

# %%
plt.figure(figsize = (15,15))
sns.barplot(x  = df['Age'], y = df['turnover_num'])

# %%
plt.figure(figsize = (15,15))
sns.barplot(data = df, x = 'TotalWorkingYears', y ='MonthlyIncome')

# %%
plt.figure(figsize  = (15,15))
sns.barplot(data = df, x = 'Age', y ='NumCompaniesWorked')

# %%
plt.figure(figsize = ( 15,15))
sns.barplot(data = df, x = 'YearsAtCompany', y = 'YearsSinceLastPromotion')

# %%
df1 = df[df['turnover_num'] == 0]
df2 = df[df['turnover_num'] == 1]

# %%
plt.figure(figsize = ( 15,15))
sns.barplot(data = df1, x = 'YearsAtCompany', y = 'YearsSinceLastPromotion')
plt.figure(figsize = ( 15,15))
sns.barplot(data = df2, x = 'YearsAtCompany', y = 'YearsSinceLastPromotion')

# %%
plt.figure(figsize = (12,12))
plt.subplot(2,2,2)
sns.distplot(df.loc[(df['turnover_num'] == 0),'WorkLifeBalance'], color = 'b', hist = False, kde = True, label = 'Still in Company')
plt.subplot(2,2,1)
sns.distplot(df.loc[(df['turnover_num'] == 1),'WorkLifeBalance'], color = 'r', hist = False, kde = True, label = 'Not in Company')
plt.title('Work Life Balance')
# Out:
# Text(0.5, 1.0, 'Work Life Balance')

# %%
hrleft = df[df['turnover_num'] == 1]
hrstay = df[df['turnover_num'] == 0]

hrleft = pd.DataFrame(hrleft.Department.value_counts()).reset_index()
hrstay = pd.DataFrame(hrstay.Department.value_counts()).reset_index()


hrmerge = pd.merge(hrleft,hrstay,how = 'inner',on = 'index')

hrmerge = hrmerge.rename(columns = {'index' : 'Department', 'Department_x': 'left', 'Department_y': 'working'})

# %%
hrmerge
# Out:
#                Department  left  working
# 0  Research & Development   133      828
# 1                   Sales    92      354
# 2         Human Resources    12       51

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(figsize=(15, 7))
plt.subplot(2,2,2)
sns.barplot(x = hrmerge['Department'], y = hrmerge['working'], color = 'b')
plt.subplot(2,2,1)
sns.barplot(x = hrmerge['Department'], y = hrmerge['left'], color = 'r')

# %%
new_df = df.drop(['YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager'], axis = 1)

# %%
new_df = pd.get_dummies(new_df, columns = ['BusinessTravel','Department','Education','JobRole','MaritalStatus'])

# %%
new_df.head()
# Out:
#    Age  DistanceFromHome EducationField  EmployeeNumber  \
# 0   41                 1  Life Sciences               1
# 1   49                 8  Life Sciences               2
# 2   37                 2          Other               4
# 3   33                 3  Life Sciences               5
# 4   27                 2        Medical               7
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  JobSatisfaction  \
# 0                        2  Female               3         2                4
# 1                        3    Male               2         2                2
# 2                        4    Male               2         1                3
# 3                        4  Female               3         1                3
# 4                        1    Male               3         1                2
#
#    MonthlyIncome  ...  JobRole_Laboratory Technician  JobRole_Manager  \
# 0           5993  ...                              0                0
# ...

# %%
X = new_df.drop(['turnover_num'], axis =1)
Y = new_df['turnover_num']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

# %%
X = X.drop(['OverTime'], axis =1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.3, random_state = 42)

# %%
ml = [LogisticRegression(),SVC(),KNeighborsClassifier(),RandomForestClassifier()]

# %%
ml[0].fit(X_train,Y_train)
# Out:
# C:\Users\cassin.thangam.edwin\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions_1 = ml[0].predict(X_test)

# %%
ml[1].fit(X_train,Y_train)
predictions_2 = ml[1].predict(X_test)
# Out:
# C:\Users\cassin.thangam.edwin\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
ml[2].fit(X_train,Y_train)
predictions_3 = ml[2].predict(X_test)

# %%
ml[3].fit(X_train,Y_train)
predictions_4 = ml[3].predict(X_test)

# %%
print("Logistic Regression",classification_report(predictions_1,Y_test))
print("\n")
print("Support Vector Classifier",classification_report(predictions_2,Y_test))
print("\n")
print("Kneighbors Classifier",classification_report(predictions_3,Y_test))
print("\n")
print("RandomForestClassifier",classification_report(predictions_4,Y_test))
# Out:
# Logistic Regression               precision    recall  f1-score   support
#
#            0       0.98      0.87      0.92       429
#            1       0.10      0.50      0.16        12
#
#     accuracy                           0.86       441
#    macro avg       0.54      0.69      0.54       441
# weighted avg       0.96      0.86      0.90       441
#
#
#
# Support Vector Classifier               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.93       441
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.86       441
#    macro avg       0.50      0.43      0.46       441
# weighted avg       1.00      0.86      0.93       441
#
#
#
# Kneighbors Classifier               precision    recall  f1-score   support
#
#            0       0.96      0.87      0.91       421
#            1       0.10      0.30      0.15        20
#
#     accuracy                           0.84       441
# ...
